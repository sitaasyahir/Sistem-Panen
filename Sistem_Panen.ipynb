# %% [markdown]
# <a href="https://colab.research.google.com/github/sitaasyahir/Sistem-Panen/blob/main/Sistem_Panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hitung_total(harga_per_kg, jumlah_kg):
    return harga_per_kg * jumlah_kg

total = hitung_total(5000, 100)
print(f"Total hasil panen: Rp{total}")
# Out:
# Total hasil panen: Rp500000
